# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
csv_path = "../Desktop/Pymoli.csv"

# %%
Pymoli_df = pd.read_csv(csv_path)
Pymoli_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Set new index to last_name
gender_df = Pymoli_df.set_index("Gender")
gender_df.head()
# Out:
#         Purchase ID             SN  Age  Item ID  \
# Gender
# Male              0        Lisim78   20      108
# Male              1    Lisovynya38   40      143
# Male              2     Ithergue48   24       92
# Male              3  Chamassasya86   24      100
# Male              4      Iskosia90   23      131
#
#                                         Item Name  Price
# Gender
# Male    Extraction, Quickblade Of Trembling Hands   3.53
# Male                            Frenzied Scimitar   1.56
# Male                                 Final Critic   4.88
# Male                                  Blindscythe   3.27
# Male                                         Fury   1.44

# %%
# Calculate the Number and Percentage by Gender
gender_total_counts = player_demographics["Gender"].value_counts()
gender_demographics_percents = gender_demographics_totals / num_players * 100
gender_demographics = pd.DataFrame({"Total Count": gender_demographics_totals, "Percentage of Players": gender_demographics_percents})

# Minor Data Munging
gender_demographics = gender_demographics.round(2)

gender_demographics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count, mask)
#     434         dtype_sum = np.float64
# --> 435     the_sum = values.sum(axis, dtype=dtype_sum)
#     436     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# ...

# %%
#Gender Demographics
gender_table = Pymoli_df["Gender"]
gender_table.head()

#Percentage and Count of Male Players
only_males = Pymoli_df.loc[Pymoli_df["Gender"] == "Male"]
male_count = only_males.count()
male_percentage = male_count/player_count
                        
                             
#Percentage and Count of Female Players
only_females = Pymoli_df.loc[Pymoli_df["Gender"] == "Female"]
female_count = only_females.count()
female_percentage = female_count/player_count

#Percentage and Count of Other / Non-Disclosed
only_other = Pymoli_df.loc[Pymoli_df["Gender"] == "Other / Non-Disclosed"]
other_count = only_other.count()
other_percentage = male_count/player_count
